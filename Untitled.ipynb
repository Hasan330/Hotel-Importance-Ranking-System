# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
# %matplotlib inline
import matplotlib as plt

# %%
df = pd.read_csv("properties.csv", sep = ';', low_memory=False)

# %%
df.head()
# Out:
#      id  stars   latitude  is_cardless  longitude  supplier_id     type  rank  \
# 0  1143    5.0  31.724306            0  35.203885            1    HOTEL   0.0
# 1  1181    4.0  31.892853            0  35.200496            1    HOTEL   0.0
# 2  1192    3.0  31.709188            0  35.200751            2  UNKNOWN   0.0
# 3  1194    4.0  31.710868            0  35.207832            2  UNKNOWN   0.0
# 4  1196    3.0  31.774278            0  35.221455            1    HOTEL   1.0
#
#           published_at  city_id        ...         cancellationPolicyTime  \
# 0  2015-05-18 00:00:00    619.0        ...                           24.0
# 1  2015-05-18 12:05:01    625.0        ...                           24.0
# 2  2016-03-30 17:11:53    619.0        ...                            0.0
# 3  2015-05-18 12:05:29    619.0        ...                            0.0
# 4  2015-05-18 12:05:31  14967.0        ...                            0.0
#
# ...
